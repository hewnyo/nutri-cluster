# %%
from src.api import fetch_food_data

# TODO: 문서에 나온 서비스명으로 변경
SERVICE_ID = "I2790"

df_raw = fetch_food_data(
    service_id=SERVICE_ID,
    start_idx=1,
    end_idx=50
)

df_raw.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from src.api import fetch_food_data
#       3 # TODO: 문서에 나온 서비스명으로 변경
#       4 SERVICE_ID = "I2790"
#
# ModuleNotFoundError: No module named 'src'

# %%
df_raw.shape, df_raw.columns.tolist()[:30]
df_raw.info()
df_raw.isna().sum().sort_values(ascending=False).head(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df_raw.shape, df_raw.columns.tolist()[:30]
#       2 df_raw.info()
#       3 df_raw.isna().sum().sort_values(ascending=False).head(20)
#
# NameError: name 'df_raw' is not defined

# %%
import os
os.makedirs("data/raw", exist_ok=True)

df_raw.to_csv("data/raw/i2790_1_50_raw.csv", index=False, encoding="utf-8-sig")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       1 import os
#       2 os.makedirs("data/raw", exist_ok=True)
# ----> 4 df_raw.to_csv("data/raw/i2790_1_50_raw.csv", index=False, encoding="utf-8-sig")
#
# NameError: name 'df_raw' is not defined
